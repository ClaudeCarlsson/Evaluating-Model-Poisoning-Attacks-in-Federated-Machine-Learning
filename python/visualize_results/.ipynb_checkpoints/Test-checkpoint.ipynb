# %% [markdown]
# # Imports

# %%
from pymongo import MongoClient

import os
import urllib

# %% [markdown]
# # Test

# %%
# MONGO settings
MONGO_HOST = "localhost" 
MONGO_PORT = 6534
MONGO_USER = "fedn_admin"
MONGO_PASS = "admin"



# Define client
client = MongoClient(host=MONGO_HOST,
                     port=MONGO_PORT, 
                     username=MONGO_USER, 
                     password=MONGO_PASS,
                    authSource="admin")


# Select the database
db = client['fedn-network']

# Test the connection
db.command('ping')

# Select the collection
#collection = db['control.validations']

# Query the collection
#for doc in collection.find():
#    print(doc)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:1394, in Pool._get_socket(self, all_credentials)
#    1393     with self.lock:
# -> 1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# OperationFailure                          Traceback (most recent call last)
# Cell In[28], line 21
#      18 db = client['fedn-network']
#      20 # Test the connection
# ---> 21 db.command('ping')
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/database.py:751, in Database.command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     748 if read_preference is None:
#     749     read_preference = ((session and session._txn_read_preference())
#     750                        or ReadPreference.PRIMARY)
# --> 751 with self.__client._socket_for_reads(
#     752         read_preference, session) as (sock_info, secondary_ok):
#     753     return self._command(sock_info, command, secondary_ok, value,
#     754                          check, allowable_errors, read_preference,
#     755                          codec_options, session=session, **kwargs)
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/mongo_client.py:1389, in MongoClient._socket_for_reads(self, read_preference, session)
#    1386 single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#    1387 server = self._select_server(read_preference, session)
# -> 1389 with self._get_socket(server, session) as sock_info:
#    1390     secondary_ok = (single and not sock_info.is_mongos) or (
#    1391         read_preference != ReadPreference.PRIMARY)
#    1392     yield sock_info, secondary_ok
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/mongo_client.py:1308, in MongoClient._get_socket(self, server, session)
#    1306     yield session._pinned_connection
#    1307     return
# -> 1308 with server.get_socket(
#    1309         self.__all_credentials, handler=err_handler) as sock_info:
#    1310     # Pin this session to the selected server or connection.
#    1311     if (in_txn and server.description.server_type in (
#    1312             SERVER_TYPE.Mongos, SERVER_TYPE.LoadBalancer)):
#    1313         session._pin(server, sock_info)
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/contextlib.py:119, in _GeneratorContextManager.__enter__(self)
#     117 del self.args, self.kwds, self.func
#     118 try:
# --> 119     return next(self.gen)
#     120 except StopIteration:
#     121     raise RuntimeError("generator didn't yield") from None
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:1331, in Pool.get_socket(self, all_credentials, handler)
#    1328 if self.enabled_for_cmap:
#    1329     listeners.publish_connection_check_out_started(self.address)
# -> 1331 sock_info = self._get_socket(all_credentials)
#    1332 if self.enabled_for_cmap:
#    1333     listeners.publish_connection_checked_out(
#    1334         self.address, sock_info.id)
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:1397, in Pool._get_socket(self, all_credentials)
#    1394         sock_info = self.sockets.popleft()
#    1395 except IndexError:
#    1396     # Can raise ConnectionFailure or CertificateError.
# -> 1397     sock_info = self.connect(all_credentials)
#    1398 else:
#    1399     if self._perished(sock_info):
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:1297, in Pool.connect(self, all_credentials)
#    1294         sock_info.hello(all_credentials)
#    1295         self.is_writable = sock_info.is_writable
# -> 1297     sock_info.check_auth(all_credentials)
#    1298 except BaseException:
#    1299     sock_info.close_socket(ConnectionClosedReason.ERROR)
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:820, in SocketInfo.check_auth(self, all_credentials)
#     817         self.authset.discard(credentials)
#     819     for credentials in cached - authset:
# --> 820         self.authenticate(credentials)
#     822 # CMAP spec says to publish the ready event only after authenticating
#     823 # the connection.
#     824 if not self.ready:
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:837, in SocketInfo.authenticate(self, credentials)
#     829 def authenticate(self, credentials):
#     830     """Log in to the server and store these credentials in `authset`.
#     831
#     832     Can raise ConnectionFailure or OperationFailure.
#    (...)
#     835       - `credentials`: A MongoCredential.
#     836     """
# --> 837     auth.authenticate(credentials, self)
#     838     self.authset.add(credentials)
#     839     # negotiated_mechanisms are no longer needed.
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/auth.py:672, in authenticate(credentials, sock_info)
#     670 mechanism = credentials.mechanism
#     671 auth_func = _AUTH_MAP.get(mechanism)
# --> 672 auth_func(credentials, sock_info)
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/auth.py:588, in _authenticate_default(credentials, sock_info)
#     584     mechs = sock_info.command(
#     585         source, cmd, publish_events=False).get(
#     586         'saslSupportedMechs', [])
#     587 if 'SCRAM-SHA-256' in mechs:
# --> 588     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     589 else:
#     590     return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/auth.py:333, in _authenticate_scram(credentials, sock_info, mechanism)
#     327 server_sig = standard_b64encode(
#     328     _hmac(server_key, auth_msg, digestmod).digest())
#     330 cmd = SON([('saslContinue', 1),
#     331            ('conversationId', res['conversationId']),
#     332            ('payload', Binary(client_final))])
# --> 333 res = sock_info.command(source, cmd)
#     335 parsed = _parse_scram_response(res['payload'])
#     336 if not compare_digest(parsed[b'v'], server_sig):
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/pool.py:710, in SocketInfo.command(self, dbname, spec, secondary_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     708     self._raise_if_not_writable(unacknowledged)
#     709 try:
# --> 710     return command(self, dbname, spec, secondary_ok,
#     711                    self.is_mongos, read_preference, codec_options,
#     712                    session, client, check, allowable_errors,
#     713                    self.address, check_keys, listeners,
#     714                    self.max_bson_size, read_concern,
#     715                    parse_write_concern_error=parse_write_concern_error,
#     716                    collation=collation,
#     717                    compression_ctx=self.compression_context,
#     718                    use_op_msg=self.op_msg_enabled,
#     719                    unacknowledged=unacknowledged,
#     720                    user_fields=user_fields,
#     721                    exhaust_allowed=exhaust_allowed)
#     722 except (OperationFailure, NotPrimaryError):
#     723     raise
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/network.py:158, in command(sock_info, dbname, spec, secondary_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     156             client._process_response(response_doc, session)
#     157         if check:
# --> 158             helpers._check_command_response(
#     159                 response_doc, sock_info.max_wire_version, allowable_errors,
#     160                 parse_write_concern_error=parse_write_concern_error)
#     161 except Exception as exc:
#     162     if publish:
#
# File ~/opt/anaconda3/envs/fedn_project/lib/python3.9/site-packages/pymongo/helpers.py:167, in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     164 elif code == 43:
#     165     raise CursorNotFound(errmsg, code, response, max_wire_version)
# --> 167 raise OperationFailure(errmsg, code, response, max_wire_version)
#
# OperationFailure: Authentication failed., full error: {'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed'}
